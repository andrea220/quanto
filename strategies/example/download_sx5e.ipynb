# %% [markdown]
# # Download SX5E Index da Bloomberg

# %%
import sys
from pathlib import Path

# Aggiungi la root del progetto al path (2 livelli sopra)
sys.path.insert(0, str(Path("../../").resolve()))

from datafetch.bbg.download_data import get_or_update_ticker
from datafetch.bbg.connection import BloombergConnection

connection = BloombergConnection()
get_or_update_ticker("SX5E", "SX5E Index", connection=connection)
connection.disconnect()
# Out:
# Missing columns for SX5E Index: ['close']
