# %%
import sys
import polars as pl
from pathlib import Path

sys.path.insert(0, str(Path("../../").resolve()))
# Path relativo alla root del progetto (2 livelli sopra da strategies/example/)
data_dir = Path("../../database") 

from engine.datafeed import DataFeed, MarketData
from engine.engine import *
from engine.factor import *
from engine.plotting import *
from engine.reports import *

# %%
# PRICES_PATH = str(project_root / 'data')
universe = ['SX5E']
start_date='2015-01-01'
end_date='2026-12-31'

# cfg = Config(universe=universe, start_date=start_date, end_date=end_date, frequency="eod")
feed = DataFeed(prices_base=data_dir)

# %%
factors = [ATR(5),
            DonchianChannels(20)]
            
researcher = Researcher(factors,
                        feed,
                        start_date, end_date,
                        frequency="eod",
                        tickers=universe)

# %%
# fig = researcher.plot(ticker="SX5E")  # Plotta automaticamente tutti i fattori
# fig.show()

# %%
class TestStrategy(Strategy):

    def __init__(self) -> None:
        super().__init__()
        self.ticker = 'SX5E'
        self.factors = [
            ATR(5),
            DonchianChannels(20)
        ]
        self.position_open = False

    def on_bar(self):
        if self.period <= 1:
            return
        close = self.market_data.get(self.ticker, 0)['close'].item()
        prev_close = self.market_data.get(self.ticker, 1)['close'].item()
        dc_upper = self.market_data.get(self.ticker, 1)['dc_20_upper'].item()
        prev_dc_upper = self.market_data.get(self.ticker, 2)['dc_20_upper'].item()
        dc_lower = self.market_data.get(self.ticker, 1)['dc_20_lower'].item()
        prev_dc_lower = self.market_data.get(self.ticker, 2)['dc_20_lower'].item()
        size = self.portfolio.cash / close

        # Open position
        if close > dc_lower and prev_close < prev_dc_lower and not self.position_open:
            self.buy(self.ticker, size)
            self.position_open = True

        # Close position
        if self.position_open:
            if close < dc_upper and prev_close > prev_dc_upper:
                self.close_position(self.ticker)
                self.position_open = False
            elif close < dc_lower:
                self.close_position(self.ticker)
                self.position_open = False

# %%
starting_balance = 100000.

exec_model = ExecutionModel(mode="on_close", slippage_bps=0.0, commission_bps=0.0)
risk = RiskManager(max_leverage=4)
reporter = ReportWriter(out_dir="backtest_reports/notebook_demo")

# %%
self = TestStrategy()
self.backtest(starting_balance, start_date, end_date, "eod", universe, feed, exec_model, risk, reporter)
# Out:
# 17:09:27 [Strategy.TestStrategy] INFO: ============================================================
# 17:09:27 [Strategy.TestStrategy] INFO: BACKTEST STARTED
# 17:09:27 [Strategy.TestStrategy] INFO: ============================================================
# 17:09:27 [Strategy.TestStrategy] INFO: Period: 2015-01-01 → 2026-12-31
# 17:09:27 [Strategy.TestStrategy] INFO: Universe: SX5E
# 17:09:27 [Strategy.TestStrategy] INFO: Starting Balance: $100,000.00
# 17:09:27 [Strategy.TestStrategy] INFO: Execution Mode: on_close
# 17:09:27 [Strategy.TestStrategy] INFO: Slippage: 0.0 bps | Commission: 0.0 bps
# 17:09:27 [Strategy.TestStrategy] INFO: ------------------------------------------------------------
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 28 shares | Type: MKT
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 28 @ $3615.59 | Notional: $100,000.00
# 17:09:27 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 28 shares | Type: MKT
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 28 @ $3558.03 | Notional: $98,090.77
# 17:09:27 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 27 shares | Type: MKT
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 27 @ $3526.48 | Notional: $95,617.29
# 17:09:27 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 27 shares | Type: MKT
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 27 @ $3327.50 | Notional: $91,244.33
# 17:09:27 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 29 shares | Type: MKT
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 29 @ $3516.15 | Notional: $100,645.45
# 17:09:27 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:27 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $3218.01 | Notional: $98,174.93
# 17:09:28 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:28 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 30 shares | Type: MKT
# 17:09:28 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 30 @ $
42 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:42 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 28 shares | Type: MKT
# 17:09:42 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 28 @ $3970.69 | Notional: $111,045.70
# 17:09:42 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:42 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 28 shares | Type: MKT
# 17:09:42 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 28 @ $3505.29 | Notional: $99,448.61
# 17:09:42 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:42 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 30 shares | Type: MKT
# 17:09:42 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 30 @ $3734.64 | Notional: $112,324.79
# 17:09:43 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:43 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:43 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $3554.80 | Notional: $109,152.63
# 17:09:43 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:43 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 33 shares | Type: MKT
# 17:09:43 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 33 @ $3532.32 | Notional: $116,350.35
# 17:09:43 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:43 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 33 shares | Type: MKT
# 17:09:43 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 33 @ $3438.46 | Notional: $112,911.21
# 17:09:43 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:43 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:43 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $3421.84 | Notional: $110,329.18
# 17:09:44 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:44 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 34 shares | Type: MKT
# 17:09:44 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 34 @ $3561.92 | Notional: $119,511.24
# 17:09:44 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:44 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 33 shares | Type: MKT
# 17:09:44 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 33 @ $3544.38 | Notional: $118,012.45
# 17:09:44 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:44 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 33 shares | Type: MKT
# 17:09:44 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 33 @ $3342.56 | Notional: $111,493.83
# 17:09:45 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:45 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:45 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $3811.24 | Notional: $120,231.39
# 17:09:45 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:46 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:46 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $4179.47 | Notional: $127,998.77
# 17:09:46 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:46 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 30 shares | Type: MKT
# 17:09:46 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 30 @ $4116.98 | Notional: $123,571.84
# 17:09:47 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:47 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:47 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $4269.64 | Notional: $131,094.54
# 17:09:47 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:47 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 30 shares | Type: MKT
# 17:09:47 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 30 @ $4257.61 | Notional: $129,510.22
# 17:09:48 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:48 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 30 shares | Type: MKT
# 17:09:48 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 30 @ $4236.60 | Notional: $128,460.18
# 17:09:48 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:48 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:48 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $4224.87 | Notional: $135,576.94
# 17:09:49 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:49 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:49 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $4131.68 | Notional: $133,731.75
# 17:09:49 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:49 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:49 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $4099.85 | Notional: $132,563.61
# 17:09:49 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:49 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:49 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $4041.75 | Notional: $130,133.09
# 17:09:50 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:50 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:50 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $4453.05 | Notional: $138,526.90
# 17:09:50 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:51 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 29 shares | Type: MKT
# 17:09:51 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 29 @ $4914.13 | Notional: $144,603.91
# 17:09:52 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:52 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:52 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $4880.42 | Notional: $149,454.22
# 17:09:53 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:53 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:53 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $4897.44 | Notional: $152,598.92
# 17:09:53 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:53 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:53 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $4862.50 | Notional: $149,914.27
# 17:09:53 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:53 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:53 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $4575.22 | Notional: $146,930.47
# 17:09:53 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:54 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 33 shares | Type: MKT
# 17:09:54 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 33 @ $4877.75 | Notional: $159,222.58
# 17:09:54 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:54 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:54 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $4851.96 | Notional: $156,705.18
# 17:09:54 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:54 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:54 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $4833.53 | Notional: $153,240.65
# 17:09:55 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:56 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 29 shares | Type: MKT
# 17:09:56 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 29 @ $5359.42 | Notional: $156,988.34
# 17:09:56 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:56 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 29 shares | Type: MKT
# 17:09:56 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 29 @ $5320.30 | Notional: $153,736.05
# 17:09:56 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:57 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 31 shares | Type: MKT
# 17:09:57 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 31 @ $4773.65 | Notional: $147,753.97
# 17:09:57 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:58 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 32 shares | Type: MKT
# 17:09:58 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 32 @ $5233.58 | Notional: $167,642.48
# 17:09:58 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:09:58 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 33 shares | Type: MKT
# 17:09:58 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 33 @ $5242.32 | Notional: $174,199.13
# 17:09:59 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:10:00 [Strategy.TestStrategy] INFO: ORDER SUBMITTED → SX5E | LONG 33 shares | Type: MKT
# 17:10:00 [Strategy.TestStrategy] INFO: ORDER FILLED → SX5E | LONG 33 @ $5542.05 | Notional: $180,589.81
# 17:10:01 [Strategy.TestStrategy] INFO: POSITION CLOSED → SX5E
# 17:10:01 [Strategy.TestStrategy] INFO: ------------------------------------------------------------
# 17:10:01 [Strategy.TestStrategy] INFO: BACKTEST COMPLETED on 2026-01-29
# 17:10:01 [Strategy.TestStrategy] INFO: ------------------------------------------------------------
# 17:10:01 [Strategy.TestStrategy] INFO: Final Balance: $188,715.30
# 17:10:01 [Strategy.TestStrategy] INFO: Total P&L: $88,715.30 (+88.72%)
# 17:10:01 [Strategy.TestStrategy] INFO: Total Trades: 109
# 17:10:01 [Strategy.TestStrategy] INFO: ============================================================

# %%
analytics = StrategyAnalytics(self)

# %%
fig = analytics.plot_price_with_signals(
    'SX5E',
    plot_factors=['dc_20_upper', 'dc_20_lower'],
    chart_type='candlestick'  # Use candlestick chart instead of line chart
)
fig.show()

# %%
analytics.plot_balance("SX5E")

# %% [markdown]
# # DataFeed DataFrame

# %%
# Carica i dati di mercato usando DataFeed
df = feed.get_market_data(start_date, end_date, 'eod', universe)
print(f"Shape: {df.shape}")
print(f"\nPrime righe:")
print(df.head())
# Out:
# Shape: (1562, 10)
#
# Prime righe:
# shape: (5, 10)
# ┌────────────┬──────────┬────────┬─────────┬───┬─────────┬──────────────┬────────────────┬──────┐
# │ date       ┆ time     ┆ ticker ┆ open    ┆ … ┆ close   ┆ volume       ┆ insertion_time ┆ type │
# │ ---        ┆ ---      ┆ ---    ┆ ---     ┆   ┆ ---     ┆ ---          ┆ ---            ┆ ---  │
# │ date       ┆ time     ┆ str    ┆ f64     ┆   ┆ f64     ┆ f64          ┆ datetime[μs]   ┆ str  │
# ╞════════════╪══════════╪════════╪═════════╪═══╪═════════╪══════════════╪════════════════╪══════╡
# │ 2020-01-02 ┆ 01:00:00 ┆ SX5E   ┆ 3754.24 ┆ … ┆ 3793.24 ┆ 3.11856191e8 ┆ 2026-01-31     ┆ eod  │
# │            ┆          ┆        ┆         ┆   ┆         ┆              ┆ 16:44:00       ┆      │
# │ 2020-01-03 ┆ 01:00:00 ┆ SX5E   ┆ 3787.57 ┆ … ┆ 3773.37 ┆ 3.23515895e8 ┆ 2026-01-31     ┆ eod  │
# │            ┆          ┆        ┆         ┆   ┆         ┆              ┆ 16:44:00       ┆      │
# │ 2020-01-06 ┆ 01:00:00 ┆ SX5E   ┆ 3764.34 ┆ … ┆ 3752.52 ┆ 2.74219019e8 ┆ 2026-01-31     ┆ eod  │
# │            ┆          ┆        ┆         ┆   ┆         ┆              ┆ 16:44:00       ┆      │
# │ 2020-01-07 ┆ 01:00:00 ┆ SX5E   ┆ 3760.09 ┆ … ┆ 3759.25 ┆ 3.05443036e8 ┆ 2026-01-31     ┆ eod  │
# │            ┆          ┆        ┆         ┆   ┆         ┆              ┆ 16:44:00       ┆      │
# │ 2020-01-08 ┆ 01:00:00 ┆ SX5E   ┆ 3752.87 ┆ … ┆ 3772.56 ┆ 3.7615726e8  ┆ 2026-01-31     ┆ eod  │
# │            ┆          ┆        ┆         ┆   ┆         ┆              ┆ 16:44:00       ┆      │
# └────────────┴──────────┴────────┴─────────┴───┴─────────┴──────────────┴────────────────┴──────┘

# %%
# feed.get_data_excel(start_date, end_date, '1m', universe)

# %%
# Crea MarketData dal DataFrame storico
market_data = MarketData.from_dataframe(df)
print(f"MarketData creato con {len(market_data.symbols())} simboli")
print(f"Current date: {market_data.current_date()}")
print(f"Current time: {market_data.current_time()}")
# Out:
# MarketData creato con 1 simboli
# Current date: 2026-01-29
# Current time: 01:00:00

# %%
# Esempi di accesso ai prezzi
print("Prezzo corrente:")
print(f"  SX5E close: ${market_data.price('SX5E', 'close'):.2f}")

print("\nPrezzo T-1 (1 bar fa):")
print(f"  SX5E close: ${market_data.price('SX5E', 'close', 1):.2f}")

print("\nUltimi 10 prezzi:")
last_10 = market_data.price('SX5E', 'close', slice(0, 10))
print(f"  Shape: {len(last_10)} valori")
print(f"  Ultimi 3: {last_10[-3:].to_list()}")
# Out:
# Prezzo corrente:
#   SX5E close: $5891.95
#
# Prezzo T-1 (1 bar fa):
#   SX5E close: $5933.20
#
# Ultimi 10 prezzi:
#   Shape: 10 valori
#   Ultimi 3: [5994.59, 5933.2, 5891.95]
