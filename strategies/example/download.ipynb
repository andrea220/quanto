# %%
import sys
from pathlib import Path

# Aggiungi la root del progetto al path (2 livelli sopra)
sys.path.insert(0, str(Path("../../").resolve()))
data_dir = Path("../../database") 

from datafetch.bbg.downloader import *
from engine.datafeed import DataFeed, MarketData

# %%
ticker = 'SX5E'

end_date = datetime.now().date()
start_date = end_date - timedelta(days=20*365)

# %%
download_or_update(ticker)

# %%
feed = DataFeed(prices_base=data_dir)

# Carica i dati di mercato usando DataFeed
df = feed.get_market_data('2025-01-01', '2026-12-31', '3m', [ticker])
print(f"Shape: {df.shape}")
print(f"\nPrime righe:")
print(df.tail())
# Out:
# Shape: (24377, 10)
#
# Prime righe:
# shape: (5, 10)
# ┌────────────┬──────────┬────────┬─────────┬───┬─────────┬────────┬─────────────────────┬──────────┐
# │ date       ┆ time     ┆ ticker ┆ open    ┆ … ┆ close   ┆ volume ┆ insertion_time      ┆ type     │
# │ ---        ┆ ---      ┆ ---    ┆ ---     ┆   ┆ ---     ┆ ---    ┆ ---                 ┆ ---      │
# │ date       ┆ time     ┆ str    ┆ f64     ┆   ┆ f64     ┆ f64    ┆ datetime[μs]        ┆ str      │
# ╞════════════╪══════════╪════════╪═════════╪═══╪═════════╪════════╪═════════════════════╪══════════╡
# │ 2026-02-03 ┆ 15:09:00 ┆ SX5E   ┆ 6001.18 ┆ … ┆ 6001.63 ┆ 0.0    ┆ 2026-02-03 15:21:00 ┆ intraday │
# │ 2026-02-03 ┆ 15:12:00 ┆ SX5E   ┆ 6001.56 ┆ … ┆ 5999.47 ┆ 0.0    ┆ 2026-02-03 15:21:00 ┆ intraday │
# │ 2026-02-03 ┆ 15:15:00 ┆ SX5E   ┆ 5997.92 ┆ … ┆ 5997.12 ┆ 0.0    ┆ 2026-02-03 15:21:00 ┆ intraday │
# │ 2026-02-03 ┆ 15:18:00 ┆ SX5E   ┆ 5997.34 ┆ … ┆ 5997.95 ┆ 0.0    ┆ 2026-02-03 15:21:00 ┆ intraday │
# │ 2026-02-03 ┆ 15:21:00 ┆ SX5E   ┆ 5996.42 ┆ … ┆ 5996.94 ┆ 0.0    ┆ 2026-02-03 15:21:00 ┆ intraday │
# └────────────┴──────────┴────────┴─────────┴───┴─────────┴────────┴─────────────────────┴──────────┘
